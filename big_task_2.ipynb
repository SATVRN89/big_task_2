# %% [markdown]
# # Big task 2
#
# Let's work a bit with JSON. It's also a useful type of data, often used alongside dataframes and various tables.
#
# The structure of the file is very simple: it shows which city can be reached from another city (where routes exist).
#
# - First, display a list of all cities from which there are routes.
# - Display a list of all cities to which there are routes.
# - And as a bonus—calculate, for each departure city, the number of cities it is possible to travel to.

# %%
import pandas as pd
import json
import warnings                   
warnings.filterwarnings('ignore')

# %%
# Open json file
with open('C:/Users/ii/Desktop/SATVRN/study/Andrei/scoring_routes.json', encoding="utf8") as json_data:
    data = json.load(json_data)

# %%
# Display a list of all cities from which there are routes
list(data.keys())
# Out:
# ['Ростов-на-Дону',
#  'Каменск-Шахтинский',
#  'Воронеж',
#  'Джубга',
#  'Москва',
#  'Шахты',
#  'Новочеркасск',
#  'Аксай',
#  'Лиски',
#  'Батайск',
#  'Тула',
#  'Санкт-Петербург',
#  'Чебоксары',
#  'Михайловск',
#  'Ставрополь',
#  'Краснодар',
#  'Кропоткин',
#  'Пятигорск',
#  'Волгодонск',
#  'Новомихайловский',
#  'Сочи',
#  'Геленджик',
#  'Туапсе',
#  'Анапа',
#  'Череповец',
#  'Ханты-Мансийск',
#  'Липецк',
#  'Таганрог',
#  'Тамбов',
#  'Старый Оскол',
#  'Сургут',
#  'Светлоград',
#  'Георгиевск',
#  'Минеральные Воды',
#  'Ессентуки',
#  'Волгоград',
#  'Вологда',
#  'Белая Калитва',
#  'Псков',
#  'Вытегра',
#  'Пудож',
#  'Смоленск',
#  'Обнинск',
#  'Армавир',
#  'Казань',
#  'Синявино',
#  'Новороссийск',
#  'Великий Новгород',
#  'Ильинский',
#  'Питкяранта',
#  'Тихорецк',
#  'Нижний Новгород',
#  'Славянск-на-Кубани',
#  'Ярославль',
#  'Киров',
#  'Прохладный',
#  'Сыктывкар',
#  'Невинномысск',
#  'Ивангород',
#  'Пушкино',
#  'Мытищи',
#  'Махачкала',
#  'Пенза',
#  'Рязань',
#  'Самара',
#  'Приморск',
#  'Саратов',
#  'Тольятти',
#  'Сызрань',
#  'Балаково',
#  'Кемерово',
#  'Новосибирск',
#  'Йошкар-Ола',
#  'Кочубеевское',
#  'Набережные Челны',
#  'Уфа',
#  'Ковров',
#  'Владимир',
#  'Орехово-Зуево',
#  'Элиста',
#  'Ахтубинск',
#  'Брянск',
#  'Пермь',
#  'Назрань',
#  'Нальчик',
#  'Кызыл',
#  'Абакан',
#  'Красноярск',
#  'Дербент',
#  'Избербаш',
#  'Каспийск',
#  'Кизляр',
#  'Владикавказ',
#  'Архангельск',
#  'Прокопьевск',
#  'Томск',
#  'Темрюк',
#  'Барнаул',
#  'Бийск',
#  'Адыгейск',
#  'Горячий Ключ',
#  'Иваново',
#  'Кореновск',
#  'Сортавала',
#  'Лахденпохья',
#  'Вельск',
#  'Белорецк',
#  'Мостовской',
#  'Ижевск',
#  'Нефтекамск',
#  'Юрга',
#  'Копейск',
#  'Новомосковск',
#  'Стерлитамак',
#  'Арзамас',
#  'Астрахань',
#  'Дзержинск',
#  'Муром',
#  'Апшеронск',
#  'Майкоп',
#  'Ульяновск',
#  'Теберда',
#  'Черкесск',
#  'Карачаевск',
#  'Воткинск',
#  'Саранск',
#  'Магнитогорск',
#  'Советск',
#  'Электросталь',
#  'Белгород',
#  'Курск',
#  'Железноводск',
#  'Кисловодск',
#  'Усть-Лабинск',
#  'Углегорск',
#  'Губкин',
#  'Ступино',
#  'Сосновый Бор',
#  'Краснокамск',
#  'Сергиев Посад',
#  'Серпухов',
#  'Белореченск',
#  'Екатеринбург',
#  'Челябинск',
#  'Крымск',
#  'Троицк',
#  'Ухта',
#  'Альметьевск',
#  'Пушкин',
#  'Гатчина',
#  'Кашира',
#  'Нижний Тагил',
#  'Аша',
#  'Сим',
#  'Тобольск',
#  'Тюмень',
#  'Гулькевичи',
#  'Тверь',
#  'Рыбинск',
#  'Курганинск',
#  'Сарапул',
#  'Жуковский',
#  'Домодедово',
#  'Елабуга',
#  'Суздаль',
#  'Оренбург',
#  'Кострома',
#  'Кировск',
#  'Афипский',
#  'Ильский',
#  'Абинск',
#  'Бугульма',
#  'Нижнекамск',
#  'Салават',
#  'Великий Устюг',
#  'Грозный',
#  'Зеленодольск',
#  'Котлас',
#  'Гай',
#  'Энем',
#  'Подольск',
#  'Светлогорск',
#  'Новокузнецк',
#  'Васильево',
#  'Городище',
#  'Калуга',
#  'Братск',
#  'Усть-Илимск',
#  'Первоуральск',
#  'Ревда',
#  'Переславль-Залесский',
#  'Псебай']

# %%
# Display a list of all cities to which there are routes
list(data.values())
# Out:
# [['Ставрополь',
#   'Минеральные Воды',
#   'Невинномысск',
#   'Приморск',
#   'Пятигорск',
#   'Тихорецк',
#   'Москва',
#   'Михайловск',
#   'Аксай',
#   'Воронеж',
#   'Каменск-Шахтинский',
#   'Лиски',
#   'Новочеркасск',
#   'Тула',
#   'Брянск',
#   'Армавир',
#   'Кизляр',
#   'Махачкала',
#   'Дербент',
#   'Волгоград',
#   'Кореновск',
#   'Краснодар',
#   'Геленджик',
#   'Горячий Ключ',
#   'Джубга',
#   'Белая Калитва',
#   'Сочи',
#   'Светлоград',
#   'Шахты',
#   'Грозный',
#   'Волгодонск',
#   'Саратов',
#   'Белгород',
#   'Курск',
#   'Ейск',
#   'Кропоткин',
#   'Мостовской',
#   'Анапа',
#   'Великий Новгород',
#   'Новороссийск',
#   'Тверь',
#   'Торжок',
#   'Белореченск',
#   'Майкоп',
#   'Санкт-Петербург',
#   'Славянск-на-Кубани',
#   'Таганрог',
#   'Нальчик',
#   'Кочубеевское',
#   'Георгиевск',
#   'Курганинск',
#   'Мытищи',
#   'Назрань',
#   'Приморско-Ахтарск',
#   'Старый Оскол',
#   'Темрюк',
#   'Усть-Лабинск',
#   'Черкесск',
#   'Элиста',
#   'Абинск',
#   'Астрахань',
#   'Ахтырский',
#   'Владикавказ',
#   'Донской',
#   'Ессентуки',
#   'Кисловодск',
#   'Красная Поляна',
#   'Прохладный',
#   'Крымск',
#   'Адыгейск',
#   'Туапсе',
#   'Новомихайловский',
#   'Сергиев Посад',
#   'Серпухов',
#   'Казань',
#   'Чебоксары',
#   'Ульяновск',
#   'Тольятти',
#   'Самара',
#   'Ступино',
#   'Кашира',
#   'Псебай'],
#  ['Москва',
#   'Ставрополь',
#   'Михайловск',
#   'Аксай',
#   'Воронеж',
#   'Лиски',
#   'Новочеркасск',
#   'Ростов-на-Дону',
#   'Тула',
#   'Таганрог',
#   'Мытищи',
#   'Белая Калитва',
#   'Волгодонск',
#   'Приморск',
#   'Старый Оскол',
#   'Белгород',
#   'Батайск',
#   'Невинномысск',
#   'Армавир',
#   'Кочубеевское',
#   'Кропоткин',
#   'Тихорецк',
#   'Светлоград',
#   'Георгиевск',
#   'Минеральные Воды',
#   'Пятигорск',
#   'Шахты',
#   'Каменск-Шахтинский',
#   'Санкт-Петербург',
#   'Тверь',
#   'Торжок',
#   'Великий Новгород',
#   'Краснодар',
#   'Славянск-на-Кубани',
#   'Темрюк',
#   'Назрань',
#   'Владикавказ',
#   'Нальчик',
#   'Курск',
#   'Грозный',
#   'Кореновск',
#   'Черкесск',
#   'Белореченск',
#   'Майкоп',
#   'Усть-Лабинск',
#   'Сочи',
#   'Анапа',
#   'Геленджик',
#   'Джубга',
#   'Новомихайловский',
#   'Туапсе',
#   'Ступино',
#   'Кашира',
#   'Псебай',
#   'Мостовской',
#   'Брянск'],
#  ['Аксай',
#   'Каменск-Шахтинский',
#   'Москва',
#   'Новочеркасск',
#   'Ростов-на-Дону',
#   'Ставрополь',
#   'Тула',
#   'Михайловск',
#   'Светлоград',
#   'Шахты',
#   'Батайск',
#   'Сызрань',
#   'Лиски',
#   'Белая Калитва',
#   'Волгодонск',
#   'Приморск',
#   'Тамбов',
#   'Невинномысск',
#   'Армавир',
#   'Кочубеевское',
#   'Кропоткин',
#   'Тихорецк',
#   'Пенза',
#   'Казань',
#   'Липецк',
#   'Георгиевск',
#   'Пятигорск',
#   'Минеральные Воды',
#   'Саратов',
#   'Горячий Ключ',
#   'Джубга',
#   'Геленджик',
#   'Новороссийск',
#   'Анапа',
#   'Туапсе',
#   'Сочи',
#   'Краснодар',
#   'Курск',
#   'Брянск',
#   'Таганрог',
#   'Сергиев Посад',
#   'Славянск-на-Кубани',
#   'Темрюк',
#   'Старый Оскол',
#   'Губкин',
#   'Белгород',
#   'Домодедово',
#   'Назрань',
#   'Владикавказ',
#   'Нальчик',
#   'Тверь',
#   'Черкесск',
#   'Санкт-Петербург',
#   'Новомихайловский',
#   'Смоленск',
#   'Калуга',
#   'Майкоп',
#   'Псебай',
#   'Мостовской',
#   'Белореченск',
#   'Усть-Лабинск',
#   'Волгоград'],
#  ['Краснодар',
#   'Кропоткин',
#   'Ставрополь',
#   'Анапа',
#   'Геленджик',
#   'Новороссийск',
#   'Сочи',
#   'Туапсе',
#   'Самара',
#   'Тольятти',
#   'Сызрань',
#   'Балаково',
#   'Саратов',
#   'Ростов-на-Дону',
#   'Таганрог',
#   'Кореновск',
#   'Батайск',
#   'Приморск',
#   'Москва',
#   'Воронеж',
#   'Тула',
#   'Астрахань',
#   'Горячий Ключ',
#   'Армавир',
#   'Новомихайловский',
#   'Гулькевичи',
#   'Темрюк',
#   'Орехово-Зуево',
#   'Владимир',
#   'Суздаль',
#   'Ковров',
#   'Элиста',
#   'Усть-Лабинск',
#   'Липецк',
#   'Новочеркасск',
#   'Шахты',
#   'Каменск-Шахтинский',
#   'Курганинск',
#   'Невинномысск',
#   'Минеральные Воды',
#   'Пятигорск',
#   'Георгиевск',
#   'Нижний Новгород',
#   'Дзержинск',
#   'Муром',
#   'Арзамас'],
#  ['Волгодонск',
#   'Воронеж',
#   'Тула',
#   'Шахты',
#   'Новочеркасск',
#   'Лиски',
#   'Аксай',
#   'Каменск-Шахтинский',
#   'Ростов-на-Дону',
#   'Ставрополь',
#   'Ульяновск',
#   'Рыбинск',
#   'Кинешма',
#   'Родники',
#   'Ржев',
#   'Санкт-Петербург',
#   'Великие Луки',
#   'Иваново',
#   'Липецк',
#   'Нижний Новгород',
#   'Светлоград',
#   'Суздаль',
#   'Брянск',
#   'Киров',
#   'Волгоград',
#   'Волжский',
#   'Тамбов',
#   'Элиста',
#   'Рязань',
#   'Переславль-Залесский',
#   'Чебоксары',
#   'Пенза',
#   'Минеральные Воды',
#   'Астрахань',
#   'Белая Калитва',
#   'Краснодар',
#   'Таганрог',
#   'Пятигорск',
#   'Псков',
#   'Новомосковск',
#   'Приморск',
#   'Армавир',
#   'Черкесск',
#   'Ейск',
#   'Череповец',
#   'Смоленск',
#   'Обнинск',
#   'Владимир',
#   'Вологда',
#   'Казань',
#   'Ковров',
#   'Набережные Челны',
#   'Балаково',
#   'Невинномысск',
#   'Кочубеевское',
#   'Кропоткин',
#   'Тихорецк',
#   'Георгиевск',
#   'Саратов',
#   'Ярославль',
#   'Владикавказ',
#   'Муром',
#   'Грозный',
#   'Дзержинск',
#   'Майкоп',
#   'Старый Оскол',
#   'Ессентуки',
#   'Кисловодск',
#   'Кострома',
#   'Славянск-на-Кубани',
#   'Темрюк',
#   'Йошкар-Ола',
#   'Белгород',
#   'Юрьевец',
#   'Усть-Лабинск',
#   'Уфа',
#   'Мостовской',
#   'Псебай',
#   'Саранск',
#   'Кировск',
#   'Кореновск',
#   'Краснослободск',
#   'Курск',
#   'Губкин',
#   'Калуга',
#   'Анапа',
#   'Ахтубинск',
#   'Белореченск',
#   'Назрань',
#   'Великий Новгород',
#   'Прохладный',
#   'Дербент',
#   'Пермь',
#   'Воткинск',
#   'Ижевск',
#   'Горячий Ключ',
#   'Джубга',
#   'Геленджик',
#   'Новороссийск',
#   'Туапсе',
#   'Сочи',
#   'Орехово-Зуево',
#   'Электросталь',
#   'Ливны',
#   'Нальчик',
#   'Самара',
#   'Оренбург',
#   'Сергиев Посад',
#   'Пушкино',
#   'Мытищи',
#   'Махачкала',
#   'Кизляр',
#   'Балашиха',
#   'Старая Купавна',
#   'Монино',
#   'Ногинск',
#   'Городище',
#   'Сызрань',
#   'Тольятти',
#   'Светлогорск',
#   'Краснокамск',
#   'Каспийск',
#   'Избербаш'],
#  ['Ставрополь',
#   'Михайловск',
#   'Светлоград',
#   'Тула',
#   'Москва',
#   'Воронеж',
#   'Ростов-на-Дону',
#   'Белая Калитва',
#   'Волгоград',
#   'Волгодонск',
#   'Старый Оскол',
#   'Белгород',
#   'Невинномысск',
#   'Армавир',
#   'Кочубеевское',
#   'Кропоткин',
#   'Тихорецк',
#   'Георгиевск',
#   'Минеральные Воды',
#   'Пятигорск',
#   'Каменск-Шахтинский',
#   'Новочеркасск',
#   'Аксай',
#   'Приморск',
#   'Краснодар',
#   'Славянск-на-Кубани',
#   'Темрюк',
#   'Назрань',
#   'Владикавказ',
#   'Нальчик',
#   'Санкт-Петербург',
#   'Лиски',
#   'Кореновск',
#   'Курск',
#   'Грозный',
#   'Брянск',
#   'Черкесск',
#   'Тверь',
#   'Белореченск',
#   'Майкоп',
#   'Усть-Лабинск',
#   'Джубга',
#   'Новомихайловский',
#   'Туапсе',
#   'Сочи',
#   'Анапа',
#   'Геленджик',
#   'Ступино',
#   'Кашира',
#   'Псебай',
#   'Мостовской'],
#  ['Ставрополь',
#   'Михайловск',
#   'Аксай',
#   'Воронеж',
#   'Каменск-Шахтинский',
#   'Лиски',
#   'Москва',
#   'Ростов-на-Дону',
#   'Тула',
#   'Волгоград',
#   'Белая Калитва',
#   'Кропоткин',
#   'Таганрог',
#   'Старый Оскол',
#   'Белгород',
#   'Светлоград',
#   'Минеральные Воды',
#   'Невинномысск',
#   'Пятигорск',
#   'Тихорецк',
#   'Армавир',
#   'Краснодар',
#   'Кочубеевское',
#   'Георгиевск',
#   'Усть-Лабинск',
#   'Белореченск',
#   'Волгодонск',
#   'Геленджик',
#   'Дербент',
#   'Джубга',
#   'Кизляр',
#   'Кореновск',
#   'Майкоп',
#   'Махачкала',
#   'Мостовской',
#   'Новороссийск',
#   'Абинск',
#   'Ахтырский',
#   'Крымск',
#   'Шахты',
#   'Назрань',
#   'Владикавказ',
#   'Нальчик',
#   'Черкесск',
#   'Санкт-Петербург',
#   'Тверь',
#   'Анапа',
#   'Новомихайловский',
#   'Туапсе',
#   'Сочи',
#   'Ступино',
#   'Кашира',
#   'Псебай'],
#  ['Ставрополь',
#   'Светлоград',
#   'Воронеж',
#   'Каменск-Шахтинский',
#   'Лиски',
#   'Москва',
#   'Новочеркасск',
#   'Ростов-на-Дону',
#   'Тула',
#   'Михайловск',
#   'Краснодар',
#   'Шахты',
#   'Георгиевск',
#   'Пятигорск',
#   'Минеральные Воды',
#   'Кропоткин',
#   'Армавир',
#   'Невинномысск',
#   'Волгодонск',
#   'Санкт-Петербург',
#   'Кореновск',
#   'Майкоп',
#   'Белореченск',
#   'Усть-Лабинск',
#   'Белгород',
#   'Ступино',
#   'Кашира',
#   'Черкесск',
#   'Псебай',
#   'Мостовской'],
#  ['Ставрополь',
#   'Ростов-на-Дону',
#   'Шахты',
#   'Каменск-Шахтинский',
#   'Новочеркасск',
#   'Аксай',
#   'Батайск',
#   'Михайловск',
#   'Воронеж',
#   'Москва',
#   'Тула',
#   'Белая Калитва',
#   'Волгодонск',
#   'Невинномысск',
#   'Армавир',
#   'Кочубеевское',
#   'Кропоткин',
#   'Тихорецк',
#   'Светлоград',
#   'Георгиевск',
#   'Пятигорск',
#   'Минеральные Воды',
#   'Славянск-на-Кубани',
#   'Темрюк',
#   'Ступино',
#   'Кашира'],
#  ['Ставрополь',
#   'Михайловск',
#   'Светлоград',
#   'Георгиевск',
#   'Пятигорск',
#   'Минеральные Воды',
#   'Джубга',
#   'Новомихайловский',
#   'Туапсе',
#   'Сочи',
#   'Краснодар',
#   'Горячий Ключ',
#   'Геленджик',
#   'Каменск-Шахтинский',
#   'Воронеж',
#   'Тула',
#   'Москва'],
#  ['Воронеж',
#   'Каменск-Шахтинский',
#   'Москва',
#   'Новочеркасск',
#   'Ростов-на-Дону',
#   'Ставрополь',
#   'Михайловск',
#   'Шахты',
#   'Аксай',
#   'Лиски',
#   'Батайск',
#   'Приморск',
#   'Невинномысск',
#   'Армавир',
#   'Кочубеевское',
#   'Кропоткин',
#   'Тихорецк',
#   'Светлоград',
#   'Георгиевск',
#   'Пятигорск',
#   'Минеральные Воды',
#   'Ейск',
#   'Анапа',
#   'Геленджик',
#   'Джубга',
#   'Новомихайловский',
#   'Сочи',
#   'Горячий Ключ',
#   'Новороссийск',
#   'Туапсе',
#   'Краснодар',
#   'Волгодонск',
#   'Сергиев Посад',
#   'Славянск-на-Кубани',
#   'Темрюк',
#   'Таганрог',
#   'Белая Калитва',
#   'Владикавказ',
#   'Нальчик',
#   'Черкесск',
#   'Санкт-Петербург',
#   'Усть-Лабинск',
#   'Белореченск',
#   'Майкоп',
#   'Мостовской',
#   'Псебай',
#   'Смоленск',
#   'Калуга'],
#  ['Псков',
#   'Ивангород',
#   'Великий Новгород',
#   'Вытегра',
#   'Пудож',
#   'Синявино',
#   'Ильинский',
#   'Питкяранта',
#   'Смоленск',
#   'Лахденпохья',
#   'Сортавала',
#   'Череповец',
#   'Вологда',
#   'Аксай',
#   'Ростов-на-Дону',
#   'Кировск',
#   'Шахты',
#   'Тула',
#   'Воронеж',
#   'Каменск-Шахтинский',
#   'Новочеркасск',
#   'Тихорецк',
#   'Кропоткин',
#   'Армавир',
#   'Невинномысск',
#   'Минеральные Воды',
#   'Пятигорск',
#   'Нальчик',
#   'Кочубеевское',
#   'Светлогорск',
#   'Брянск',
#   'Волгоград',
#   'Элиста',
#   'Махачкала',
#   'Кизляр',
#   'Тамбов',
#   'Тверь',
#   'Каспийск',
#   'Дербент',
#   'Избербаш'],
#  ['Москва',
#   'Йошкар-Ола',
#   'Киров',
#   'Сыктывкар',
#   'Казань',
#   'Уфа',
#   'Ижевск',
#   'Набережные Челны',
#   'Ковров',
#   'Орехово-Зуево',
#   'Электросталь',
#   'Нижний Новгород',
#   'Ульяновск',
#   'Оренбург',
#   'Волгоград',
#   'Ростов-на-Дону',
#   'Краснодар',
#   'Анапа',
#   'Дзержинск',
#   'Ногинск',
#   'Монино',
#   'Старая Купавна',
#   'Воткинск',
#   'Краснокамск',
#   'Пермь',
#   'Владимир',
#   'Балашиха',
#   'Советск'],
#  ['Новочеркасск',
#   'Каменск-Шахтинский',
#   'Георгиевск',
#   'Пятигорск',
#   'Минеральные Воды',
#   'Невинномысск',
#   'Краснодар',
#   'Усть-Лабинск',
#   'Кропоткин',
#   'Владикавказ',
#   'Нальчик',
#   'Батайск',
#   'Аксай',
#   'Ростов-на-Дону',
#   'Шахты',
#   'Воронеж',
#   'Тула',
#   'Москва'],
#  ['Аксай',
#   'Воронеж',
#   'Джубга',
#   'Каменск-Шахтинский',
#   'Краснодар',
#   'Кропоткин',
#   'Лиски',
#   'Москва',
#   'Новомихайловский',
#   'Новочеркасск',
#   'Ростов-на-Дону',
#   'Сочи',
#   'Туапсе',
#   'Тула',
#   'Шахты',
#   'Пятигорск',
#   'Георгиевск',
#   'Минеральные Воды',
#   'Владикавказ',
#   'Серпухов',
#   'Железноводск',
#   'Ессентуки',
#   'Кисловодск',
#   'Невинномысск',
#   'Армавир',
#   'Тихорецк',
#   'Горячий Ключ',
#   'Геленджик',
#   'Кочубеевское',
#   'Нальчик',
#   'Назрань',
#   'Грозный',
#   'Усть-Лабинск',
#   'Анапа',
#   'Светлоград',
#   'Элиста',
#   'Волгоград',
#   'Астрахань',
#   'Новороссийск',
#   'Майкоп',
#   'Черкесск',
#   'Карачаевск',
#   'Теберда',
#   'Энем',
#   'Ильский',
#   'Абинск',
#   'Крымск',
#   'Батайск',
#   'Ставрополь'],
#  ['Ставрополь',
#   'Кропоткин',
#   'Джубга',
#   'Новомихайловский',
#   'Сочи',
#   'Туапсе',
#   'Москва',
#   'Ростов-на-Дону',
#   'Воронеж',
#   'Таганрог',
#   'Астрахань',
#   'Элиста',
#   'Батайск',
#   'Горячий Ключ',
#   'Геленджик',
#   'Владикавказ',
#   'Минеральные Воды',
#   'Пятигорск',
#   'Кореновск',
#   'Приморск',
#   'Славянск-на-Кубани',
#   'Темрюк',
#   'Лиски',
#   'Тула',
#   'Георгиевск',
#   'Адыгейск',
#   'Прохладный',
#   'Каменск-Шахтинский',
#   'Шахты',
#   'Белгород',
#   'Армавир',
#   'Невинномысск',
#   'Михайловск',
#   'Новороссийск',
#   'Казань',
#   'Анапа',
#   'Брянск',
#   'Курск',
#   'Чебоксары',
#   'Ульяновск',
#   'Тольятти',
#   'Самара',
#   'Саратов',
#   'Аксай',
#   'Новочеркасск'],
#  ['Джубга',
#   'Краснодар',
#   'Новомихайловский',
#   'Сочи',
#   'Туапсе',
#   'Новочеркасск',
#   'Ростов-на-Дону',
#   'Воронеж',
#   'Тула',
#   'Шахты',
#   'Каменск-Шахтинский',
#   'Москва',
#   'Лиски',
#   'Астрахань',
#   'Элиста',
#   'Славянск-на-Кубани',
#   'Темрюк',
#   'Ессентуки',
#   'Пятигорск',
#   'Минеральные Воды',
#   'Армавир',
#   'Невинномысск',
#   'Ставрополь',
#   'Таганрог',
#   'Кисловодск',
#   'Приморск',
#   'Тихорецк',
#   'Горячий Ключ',
#   'Михайловск',
#   'Геленджик',
#   'Владикавказ',
#   'Санкт-Петербург',
#   'Тверь',
#   'Георгиевск',
#   'Курск',
#   'Белгород',
#   'Брянск',
#   'Энем',
#   'Ильский',
#   'Анапа',
#   'Новороссийск',
#   'Абинск',
#   'Крымск'],
#  ['Москва',
#   'Ростов-на-Дону',
#   'Тула',
#   'Шахты',
#   'Каменск-Шахтинский',
#   'Новочеркасск',
#   'Аксай',
#   'Воронеж',
#   'Владикавказ',
#   'Ставрополь',
#   'Махачкала',
#   'Элиста',
#   'Краснодар',
#   'Волгоград',
#   'Майкоп',
#   'Карачаевск',
#   'Кизляр',
#   'Невинномысск',
#   'Черкесск',
#   'Джубга',
#   'Армавир',
#   'Саратов',
#   'Кропоткин',
#   'Новомихайловский',
#   'Сочи',
#   'Тихорецк',
#   'Туапсе',
#   'Прохладный',
#   'Волгодонск',
#   'Минеральные Воды',
#   'Астрахань',
#   'Светлоград',
#   'Дербент',
#   'Таганрог',
#   'Нальчик',
#   'Назрань',
#   'Грозный',
#   'Приморск',
#   'Михайловск',
#   'Балаково',
#   'Сызрань',
#   'Тольятти',
#   'Самара',
#   'Уфа',
#   'Санкт-Петербург',
#   'Тверь',
#   'Курск',
#   'Белгород',
#   'Брянск',
#   'Горячий Ключ',
#   'Геленджик',
#   'Новороссийск',
#   'Анапа'],
#  ['Белая Калитва',
#   'Воронеж',
#   'Каменск-Шахтинский',
#   'Лиски',
#   'Тула',
#   'Москва',
#   'Ростов-на-Дону',
#   'Новочеркасск',
#   'Шахты',
#   'Аксай'],
#  ['Джубга',
#   'Краснодар',
#   'Кропоткин',
#   'Ставрополь',
#   'Самара',
#   'Тольятти',
#   'Сызрань',
#   'Балаково',
#   'Саратов',
#   'Астрахань',
#   'Армавир',
#   'Горячий Ключ',
#   'Сочи',
#   'Туапсе',
#   'Гулькевичи',
#   'Курганинск',
#   'Геленджик',
#   'Элиста',
#   'Усть-Лабинск',
#   'Липецк',
#   'Воронеж',
#   'Ростов-на-Дону',
#   'Новочеркасск',
#   'Шахты',
#   'Каменск-Шахтинский',
#   'Невинномысск',
#   'Минеральные Воды',
#   'Пятигорск',
#   'Георгиевск',
#   'Нижний Новгород',
#   'Дзержинск',
#   'Арзамас',
#   'Муром'],
#  ['Джубга',
#   'Краснодар',
#   'Кропоткин',
#   'Новомихайловский',
#   'Ставрополь',
#   'Туапсе',
#   'Анапа',
#   'Геленджик',
#   'Новороссийск',
#   'Ростов-на-Дону',
#   'Таганрог',
#   'Кореновск',
#   'Батайск',
#   'Приморск',
#   'Сочи',
#   'Воронеж',
#   'Тула',
#   'Москва',
#   'Астрахань',
#   'Армавир',
#   'Горячий Ключ',
#   'Темрюк',
#   'Элиста',
#   'Усть-Лабинск',
#   'Новочеркасск',
#   'Шахты',
#   'Каменск-Шахтинский',
#   'Липецк'],
#  ['Анапа',
#   'Джубга',
#   'Новороссийск',
#   'Сочи',
#   'Туапсе',
#   'Ковров',
#   'Владимир',
#   'Орехово-Зуево',
#   'Краснодар',
#   'Кореновск',
#   'Батайск',
#   'Ростов-на-Дону',
#   'Таганрог',
#   'Приморск',
#   'Самара',
#   'Тольятти',
#   'Сызрань',
#   'Балаково',
#   'Москва',
#   'Воронеж',
#   'Тула',
#   'Астрахань',
#   'Горячий Ключ',
#   'Кропоткин',
#   'Гулькевичи',
#   'Темрюк',
#   'Новомихайловский',
#   'Адыгейск',
#   'Брянск',
#   'Курск',
#   'Суздаль',
#   'Шахты',
#   'Каменск-Шахтинский',
#   'Саранск',
#   'Ульяновск',
#   'Элиста',
#   'Ставрополь',
#   'Усть-Лабинск',
#   'Новочеркасск',
#   'Армавир',
#   'Курганинск',
#   'Невинномысск',
#   'Минеральные Воды',
#   'Пятигорск',
#   'Георгиевск',
#   'Липецк',
#   'Нижний Новгород',
#   'Дзержинск',
#   'Муром',
#   'Арзамас'],
#  ['Джубга',
#   'Краснодар',
#   'Кропоткин',
#   'Новомихайловский',
#   'Ставрополь',
#   'Анапа',
#   'Геленджик',
#   'Новороссийск',
#   'Сочи',
#   'Горячий Ключ',
#   'Ростов-на-Дону',
#   'Таганрог',
#   'Кореновск',
#   'Батайск',
#   'Приморск',
#   'Самара',
#   'Тольятти',
#   'Сызрань',
#   'Балаково',
#   'Воронеж',
#   'Тула',
#   'Москва',
#   'Астрахань',
#   'Армавир',
#   'Темрюк',
#   'Элиста',
#   'Усть-Лабинск',
#   'Липецк',
#   'Новочеркасск',
#   'Шахты',
#   'Каменск-Шахтинский',
#   'Невинномысск',
#   'Минеральные Воды',
#   'Пятигорск',
#   'Георгиевск',
#   'Нижний Новгород',
#   'Дзержинск',
#   'Арзамас',
#   'Муром'],
#  ['Геленджик',
#   'Джубга',
#   'Новороссийск',
#   'Сочи',
#   'Туапсе',
#   'Воронеж',
#   'Москва',
#   'Тула',
#   'Самара',
#   'Тольятти',
#   'Сызрань',
#   'Балаково',
#   'Саратов',
#   'Краснодар',
#   'Приморск',
#   'Владикавказ',
#   'Ростов-на-Дону',
#   'Казань',
#   'Темрюк',
#   'Брянск',
#   'Курск',
#   'Орехово-Зуево',
#   'Владимир',
#   'Суздаль',
#   'Ковров',
#   'Шахты',
#   'Каменск-Шахтинский',
#   'Саранск',
#   'Ульяновск',
#   'Чебоксары',
#   'Волгоград',
#   'Элиста',
#   'Астрахань',
#   'Ставрополь',
#   'Кропоткин',
#   'Усть-Лабинск',
#   'Новочеркасск',
#   'Армавир',
#   'Невинномысск',
#   'Минеральные Воды',
#   'Пятигорск',
#   'Георгиевск',
#   'Липецк',
#   'Нижний Новгород',
#   'Дзержинск',
#   'Арзамас',
#   'Муром'],
#  ['Москва',
#   'Вологда',
#   'Ярославль',
#   'Котлас',
#   'Великий Устюг',
#   'Санкт-Петербург',
#   'Переславль-Залесский',
#   'Сергиев Посад',
#   'Домодедово'],
#  ['Сургут', 'Тобольск', 'Тюмень'],
#  ['Москва',
#   'Воронеж',
#   'Сызрань',
#   'Казань',
#   'Пенза',
#   'Тамбов',
#   'Тула',
#   'Туапсе',
#   'Джубга',
#   'Новомихайловский',
#   'Анапа',
#   'Геленджик',
#   'Сочи',
#   'Новороссийск',
#   'Домодедово'],
#  ['Волгоград',
#   'Москва',
#   'Ростов-на-Дону',
#   'Ставрополь',
#   'Тихорецк',
#   'Приморск',
#   'Каменск-Шахтинский',
#   'Новочеркасск',
#   'Шахты',
#   'Астрахань',
#   'Белая Калитва',
#   'Волгодонск',
#   'Воронеж',
#   'Ейск',
#   'Мытищи',
#   'Элиста',
#   'Абинск',
#   'Армавир',
#   'Геленджик',
#   'Кореновск',
#   'Краснодар',
#   'Кропоткин',
#   'Новороссийск',
#   'Адыгейск',
#   'Горячий Ключ',
#   'Сочи',
#   'Джубга',
#   'Туапсе',
#   'Новомихайловский',
#   'Тула',
#   'Минеральные Воды',
#   'Невинномысск',
#   'Кисловодск',
#   'Ессентуки',
#   'Пятигорск'],
#  ['Воронеж',
#   'Липецк',
#   'Казань',
#   'Пенза',
#   'Сызрань',
#   'Владимир',
#   'Иваново',
#   'Рязань',
#   'Москва',
#   'Волгоград',
#   'Элиста',
#   'Каспийск',
#   'Дербент',
#   'Избербаш',
#   'Махачкала',
#   'Кизляр',
#   'Санкт-Петербург',
#   'Великий Новгород',
#   'Тверь'],
#  ['Воронеж', 'Липецк', 'Белгород', 'Саратов', 'Москва', 'Волгоград'],
#  ['Ханты-Мансийск'],
#  ['Ростов-на-Дону',
#   'Тула',
#   'Шахты',
#   'Каменск-Шахтинский',
#   'Новочеркасск',
#   'Аксай',
#   'Москва',
#   'Воронеж',
#   'Волгоград',
#   'Элиста',
#   'Астрахань',
#   'Ступино',
#   'Кашира'],
#  ['Ростов-на-Дону',
#   'Тула',
#   'Шахты',
#   'Каменск-Шахтинский',
#   'Новочеркасск',
#   'Аксай',
#   'Москва',
#   'Воронеж',
#   'Невинномысск',
#   'Тихорецк',
#   'Армавир',
#   'Краснодар',
#   'Кропоткин',
#   'Горячий Ключ',
#   'Джубга',
#   'Геленджик',
#   'Новороссийск',
#   'Анапа',
#   'Новомихайловский',
#   'Туапсе'],
#  ['Ростов-на-Дону',
#   'Тула',
#   'Шахты',
#   'Каменск-Шахтинский',
#   'Новочеркасск',
#   'Аксай',
#   'Москва',
#   'Воронеж',
#   'Краснодар',
#   'Ставрополь',
#   'Волгоград',
#   'Майкоп',
#   'Кропоткин',
#   'Астрахань',
#   'Армавир',
#   'Черкесск',
#   'Невинномысск',
#   'Тихорецк',
#   'Карачаевск',
#   'Джубга',
#   'Новомихайловский',
#   'Саратов',
#   'Сочи',
#   'Туапсе',
#   'Элиста',
#   'Прохладный',
#   'Волгодонск',
#   'Нальчик',
#   'Анапа',
#   'Владикавказ',
#   'Светлоград',
#   'Махачкала',
#   'Дербент',
#   'Таганрог',
#   'Приморск',
#   'Сергиев Посад',
#   'Серпухов',
#   'Михайловск',
#   'Назрань',
#   'Грозный',
#   'Балаково',
#   'Сызрань',
#   'Тольятти',
#   'Самара',
#   'Уфа',
#   'Темрюк',
#   'Славянск-на-Кубани',
#   'Санкт-Петербург',
#   'Тверь',
#   'Горячий Ключ',
#   'Геленджик',
#   'Новороссийск',
#   'Курск',
#   'Белгород',
#   'Брянск'],
#  ['Ставрополь',
#   'Армавир',
#   'Джубга',
#   'Краснодар',
#   'Кропоткин',
#   'Невинномысск',
#   'Новомихайловский',
#   'Сочи',
#   'Туапсе',
#   'Воронеж',
#   'Тула',
#   'Ростов-на-Дону',
#   'Прохладный',
#   'Владикавказ',
#   'Каменск-Шахтинский',
#   'Астрахань',
#   'Москва',
#   'Элиста',
#   'Махачкала',
#   'Дербент',
#   'Нальчик'],
#  ['Волгодонск',
#   'Новочеркасск',
#   'Ростов-на-Дону',
#   'Таганрог',
#   'Белая Калитва',
#   'Шахты',
#   'Казань',
#   'Назрань',
#   'Владикавказ',
#   'Нальчик',
#   'Пятигорск',
#   'Минеральные Воды',
#   'Элиста',
#   'Саратов',
#   'Балаково',
#   'Сызрань',
#   'Тольятти',
#   'Самара',
#   'Уфа',
#   'Чебоксары',
#   'Ульяновск',
#   'Анапа',
#   'Москва',
#   'Дербент',
#   'Избербаш',
#   'Махачкала',
#   'Кизляр',
#   'Ставрополь',
#   'Нижний Новгород',
#   'Арзамас',
#   'Саранск',
#   'Пенза',
#   'Каспийск',
#   'Тамбов',
#   'Владимир',
#   'Иваново',
#   'Воронеж',
#   'Славянск-на-Кубани',
#   'Темрюк',
#   'Старый Оскол',
#   'Губкин',
#   'Белгород',
#   'Санкт-Петербург',
#   'Великий Новгород',
#   'Тверь',
#   'Тихорецк',
#   'Краснодар'],
#  ['Москва',
#   'Ярославль',
#   'Череповец',
#   'Иваново',
#   'Нижний Новгород',
#   'Котлас',
#   'Великий Устюг',
#   'Вытегра',
#   'Кострома',
#   'Санкт-Петербург',
#   'Вельск',
#   'Домодедово',
#   'Жуковский',
#   'Архангельск'],
#  ['Новочеркасск',
#   'Шахты',
#   'Ростов-на-Дону',
#   'Таганрог',
#   'Волгоград',
#   'Волгодонск',
#   'Саратов',
#   'Москва',
#   'Воронеж',
#   'Каменск-Шахтинский',
#   'Лиски',
#   'Тула',
#   'Курск',
#   'Славянск-на-Кубани',
#   'Темрюк'],
#  ['Великий Новгород',
#   'Санкт-Петербург',
#   'Смоленск',
#   'Москва',
#   'Кировск',
#   'Гатчина',
#   'Брянск'],
#  ['Санкт-Петербург', 'Пудож', 'Вологда', 'Ярославль'],
#  ['Санкт-Петербург', 'Вытегра'],
#  ['Псков', 'Санкт-Петербург', 'Москва', 'Калуга', 'Тула', 'Воронеж', 'Брянск'],
#  ['Москва'],
#  ['Москва',
#   'Ростов-на-Дону',
#   'Воронеж',
#   'Тула',
#   'Шахты',
#   'Каменск-Шахтинский',
#   'Новочеркасск',
#   'Лиски',
#   'Георгиевск',
#   'Минеральные Воды',
#   'Невинномысск',
#   'Пятигорск',
#   'Астрахань',
#   'Ставрополь',
#   'Таганрог',
#   'Кисловодск',
#   'Ессентуки',
#   'Приморск',
#   'Краснодар',
#   'Кропоткин',
#   'Тихорецк',
#   'Сочи',
#   'Туапсе',
#   'Горячий Ключ',
#   'Джубга',
#   'Новомихайловский',
#   'Анапа',
#   'Владикавказ',
#   'Темрюк',
#   'Санкт-Петербург',
#   'Тверь',
#   'Геленджик',
#   'Новороссийск',
#   'Курск',
#   'Белгород',
#   'Брянск'],
#  ['Самара',
#   'Москва',
#   'Нижний Новгород',
#   'Стерлитамак',
#   'Ижевск',
#   'Набережные Челны',
#   'Киров',
#   'Йошкар-Ола',
#   'Воткинск',
#   'Пермь',
#   'Ковров',
#   'Орехово-Зуево',
#   'Электросталь',
#   'Советск',
#   'Сыктывкар',
#   'Тольятти',
#   'Волгоград',
#   'Ростов-на-Дону',
#   'Краснодар',
#   'Анапа',
#   'Уфа',
#   'Ногинск',
#   'Монино',
#   'Старая Купавна',
#   'Елабуга',
#   'Ухта',
#   'Астрахань',
#   'Владимир',
#   'Кизляр',
#   'Элиста',
#   'Саратов',
#   'Сызрань',
#   'Дербент',
#   'Избербаш',
#   'Махачкала',
#   'Ульяновск',
#   'Альметьевск',
#   'Чебоксары',
#   'Салават',
#   'Балашиха',
#   'Дзержинск',
#   'Бугульма',
#   'Оренбург'],
#  [],
#  ['Анапа',
#   'Геленджик',
#   'Джубга',
#   'Сочи',
#   'Туапсе',
#   'Приморск',
#   'Самара',
#   'Тольятти',
#   'Сызрань',
#   'Балаково',
#   'Москва',
#   'Воронеж',
#   'Тула',
#   'Ростов-на-Дону',
#   'Краснодар',
#   'Темрюк',
#   'Брянск',
#   'Курск',
#   'Нижний Новгород',
#   'Дзержинск',
#   'Арзамас',
#   'Муром',
#   'Ставрополь',
#   'Кропоткин',
#   'Армавир',
#   'Невинномысск',
#   'Минеральные Воды',
#   'Пятигорск',
#   'Георгиевск',
#   'Липецк'],
#  ['Санкт-Петербург',
#   'Псков',
#   'Москва',
#   'Махачкала',
#   'Волгоград',
#   'Элиста',
#   'Кизляр',
#   'Тамбов',
#   'Каспийск',
#   'Дербент',
#   'Избербаш'],
#  ['Санкт-Петербург', 'Питкяранта'],
#  ['Санкт-Петербург', 'Ильинский'],
#  ['Ростов-на-Дону',
#   'Москва',
#   'Воронеж',
#   'Тула',
#   'Шахты',
#   'Каменск-Шахтинский',
#   'Новочеркасск',
#   'Лиски',
#   'Ессентуки',
#   'Пятигорск',
#   'Минеральные Воды',
#   'Владикавказ',
#   'Армавир',
#   'Кропоткин',
#   'Санкт-Петербург',
#   'Тверь'],
#  ['Москва',
#   'Вологда',
#   'Ярославль',
#   'Иваново',
#   'Ижевск',
#   'Казань',
#   'Набережные Челны',
#   'Чебоксары',
#   'Воткинск',
#   'Пермь',
#   'Орехово-Зуево',
#   'Электросталь',
#   'Дзержинск',
#   'Ковров',
#   'Уфа',
#   'Ульяновск',
#   'Оренбург',
#   'Саратов',
#   'Арзамас',
#   'Саранск',
#   'Пенза',
#   'Волгоград',
#   'Владимир',
#   'Дербент',
#   'Избербаш',
#   'Каспийск',
#   'Махачкала',
#   'Кизляр',
#   'Элиста',
#   'Балашиха',
#   'Новороссийск',
#   'Самара',
#   'Тольятти',
#   'Геленджик',
#   'Джубга',
#   'Туапсе',
#   'Новомихайловский',
#   'Анапа'],
#  ['Воронеж',
#   'Тула',
#   'Москва',
#   'Краснодар',
#   'Ростов-на-Дону',
#   'Элиста',
#   'Астрахань',
#   'Кропоткин',
#   'Темрюк',
#   'Каменск-Шахтинский',
#   'Шахты',
#   'Белгород',
#   'Лиски',
#   'Усть-Лабинск',
#   'Минеральные Воды',
#   'Белая Калитва',
#   'Волгоград',
#   'Брянск',
#   'Курск'],
#  ['Вологда',
#   'Москва',
#   'Череповец',
#   'Иваново',
#   'Нижний Новгород',
#   'Владикавказ',
#   'Кострома',
#   'Домодедово',
#   'Вельск',
#   'Вытегра',
#   'Великий Устюг',
#   'Котлас',
#   'Жуковский'],
#  ['Йошкар-Ола',
#   'Сыктывкар',
#   'Казань',
#   'Чебоксары',
#   'Уфа',
#   'Набережные Челны',
#   'Ухта',
#   'Советск',
#   'Москва',
#   'Зеленодольск',
#   'Ижевск',
#   'Сарапул',
#   'Нефтекамск',
#   'Самара',
#   'Ульяновск',
#   'Стерлитамак',
#   'Елабуга',
#   'Васильево'],
#  ['Минеральные Воды',
#   'Москва',
#   'Невинномысск',
#   'Пятигорск',
#   'Тихорецк',
#   'Краснодар',
#   'Ростов-на-Дону',
#   'Ставрополь'],
#  ['Киров',
#   'Йошкар-Ола',
#   'Казань',
#   'Набережные Челны',
#   'Уфа',
#   'Чебоксары',
#   'Самара',
#   'Ухта',
#   'Ульяновск',
#   'Москва',
#   'Стерлитамак',
#   'Котлас',
#   'Великий Устюг'],
#  ['Ростов-на-Дону',
#   'Воронеж',
#   'Тула',
#   'Шахты',
#   'Каменск-Шахтинский',
#   'Новочеркасск',
#   'Москва',
#   'Лиски',
#   'Краснодар',
#   'Новороссийск',
#   'Армавир',
#   'Серпухов',
#   'Черкесск',
#   'Пятигорск',
#   'Таганрог',
#   'Приморск',
#   'Ставрополь',
#   'Минеральные Воды',
#   'Владикавказ',
#   'Михайловск',
#   'Нальчик',
#   'Назрань',
#   'Грозный',
#   'Анапа',
#   'Темрюк',
#   'Санкт-Петербург',
#   'Тверь',
#   'Карачаевск',
#   'Теберда',
#   'Кропоткин',
#   'Горячий Ключ',
#   'Джубга',
#   'Геленджик',
#   'Курск',
#   'Белгород',
#   'Брянск',
#   'Новомихайловский',
#   'Туапсе'],
#  ['Санкт-Петербург'],
#  ['Вологда', 'Череповец', 'Мытищи', 'Домодедово', 'Москва', 'Жуковский'],
#  ['Вологда',
#   'Череповец',
#   'Переславль-Залесский',
#   'Ярославль',
#   'Домодедово',
#   'Москва',
#   'Жуковский'],
#  ['Пятигорск',
#   'Кисловодск',
#   'Ессентуки',
#   'Нальчик',
#   'Невинномысск',
#   'Армавир',
#   'Кропоткин',
#   'Краснодар',
#   'Новороссийск',
#   'Великий Новгород',
#   'Москва',
#   'Астрахань',
#   'Элиста',
#   'Волгоград',
#   'Саратов',
#   'Сызрань',
#   'Ульяновск',
#   'Казань',
#   'Пенза',
#   'Саранск',
#   'Нижний Новгород',
#   'Владимир',
#   'Иваново',
#   'Тамбов',
#   'Санкт-Петербург',
#   'Тверь'],
#  ['Москва',
#   'Нижний Новгород',
#   'Саратов',
#   'Городище',
#   'Сызрань',
#   'Тольятти',
#   'Самара',
#   'Оренбург',
#   'Арзамас',
#   'Саранск',
#   'Волгоград',
#   'Дербент',
#   'Избербаш',
#   'Каспийск',
#   'Махачкала',
#   'Кизляр',
#   'Элиста'],
#  ['Москва'],
#  ['Казань',
#   'Новомихайловский',
#   'Джубга',
#   'Анапа',
#   'Геленджик',
#   'Новороссийск',
#   'Туапсе',
#   'Киров',
#   'Йошкар-Ола',
#   'Сыктывкар',
#   'Нальчик',
#   'Пятигорск',
#   'Минеральные Воды',
#   'Элиста',
#   'Волгоград',
#   'Саратов',
#   'Балаково',
#   'Назрань',
#   'Владикавказ',
#   'Уфа',
#   'Тольятти',
#   'Ростов-на-Дону',
#   'Краснодар',
#   'Ухта',
#   'Ульяновск',
#   'Нижний Новгород',
#   'Москва'],
#  ['Воронеж',
#   'Каменск-Шахтинский',
#   'Москва',
#   'Ростов-на-Дону',
#   'Горячий Ключ',
#   'Адыгейск',
#   'Сочи',
#   'Таганрог',
#   'Шахты',
#   'Тула',
#   'Краснодар',
#   'Туапсе',
#   'Джубга',
#   'Минеральные Воды',
#   'Невинномысск',
#   'Армавир',
#   'Кропоткин',
#   'Кисловодск',
#   'Ессентуки',
#   'Пятигорск'],
#  ['Новомихайловский',
#   'Джубга',
#   'Анапа',
#   'Белгород',
#   'Старый Оскол',
#   'Воронеж',
#   'Элиста',
#   'Волгоград',
#   'Назрань',
#   'Владикавказ',
#   'Нальчик',
#   'Пятигорск',
#   'Минеральные Воды',
#   'Самара',
#   'Уфа',
#   'Ростов-на-Дону',
#   'Краснодар',
#   'Астрахань',
#   'Липецк',
#   'Дербент',
#   'Избербаш',
#   'Махачкала',
#   'Кизляр',
#   'Казань',
#   'Нижний Новгород',
#   'Арзамас',
#   'Саранск',
#   'Пенза',
#   'Губкин',
#   'Каспийск'],
#  ['Новомихайловский',
#   'Джубга',
#   'Анапа',
#   'Туапсе',
#   'Геленджик',
#   'Новороссийск',
#   'Казань',
#   'Назрань',
#   'Владикавказ',
#   'Нальчик',
#   'Пятигорск',
#   'Минеральные Воды',
#   'Элиста',
#   'Волгоград',
#   'Уфа',
#   'Ростов-на-Дону',
#   'Краснодар',
#   'Ульяновск',
#   'Нижний Новгород'],
#  ['Новомихайловский',
#   'Джубга',
#   'Анапа',
#   'Туапсе',
#   'Геленджик',
#   'Новороссийск',
#   'Назрань',
#   'Владикавказ',
#   'Нальчик',
#   'Пятигорск',
#   'Минеральные Воды',
#   'Элиста',
#   'Волгоград',
#   'Уфа',
#   'Астрахань',
#   'Дербент',
#   'Избербаш',
#   'Махачкала',
#   'Кизляр',
#   'Оренбург'],
#  ['Новомихайловский',
#   'Джубга',
#   'Анапа',
#   'Туапсе',
#   'Геленджик',
#   'Новороссийск',
#   'Назрань',
#   'Владикавказ',
#   'Нальчик',
#   'Пятигорск',
#   'Минеральные Воды',
#   'Элиста',
#   'Волгоград',
#   'Самара',
#   'Уфа'],
#  ['Новосибирск', 'Юрга', 'Томск'],
#  ['Кемерово', 'Томск', 'Юрга', 'Новокузнецк', 'Прокопьевск'],
#  ['Казань',
#   'Киров',
#   'Сыктывкар',
#   'Чебоксары',
#   'Советск',
#   'Самара',
#   'Зеленодольск',
#   'Ухта'],
#  ['Воронеж',
#   'Ростов-на-Дону',
#   'Тула',
#   'Шахты',
#   'Каменск-Шахтинский',
#   'Новочеркасск',
#   'Москва',
#   'Лиски',
#   'Тверь',
#   'Санкт-Петербург'],
#  ['Сыктывкар',
#   'Нижний Новгород',
#   'Москва',
#   'Киров',
#   'Стерлитамак',
#   'Ижевск',
#   'Воткинск',
#   'Ковров',
#   'Орехово-Зуево',
#   'Электросталь',
#   'Казань',
#   'Уфа',
#   'Пермь',
#   'Сосновый Бор',
#   'Краснокамск',
#   'Бугульма',
#   'Альметьевск',
#   'Чебоксары',
#   'Дзержинск',
#   'Ногинск',
#   'Монино',
#   'Старая Купавна',
#   'Балашиха',
#   'Ухта',
#   'Владимир',
#   'Салават'],
#  ['Москва',
#   'Киров',
#   'Набережные Челны',
#   'Сыктывкар',
#   'Нижний Новгород',
#   'Пермь',
#   'Чебоксары',
#   'Стерлитамак',
#   'Салават',
#   'Магнитогорск',
#   'Казань',
#   'Екатеринбург',
#   'Первоуральск',
#   'Ижевск',
#   'Нефтекамск',
#   'Белорецк',
#   'Альметьевск',
#   'Елабуга',
#   'Ухта',
#   'Сарапул',
#   'Ревда'],
#  ['Геленджик',
#   'Пермь',
#   'Воткинск',
#   'Ижевск',
#   'Набережные Челны',
#   'Казань',
#   'Чебоксары',
#   'Нижний Новгород',
#   'Дзержинск',
#   'Владимир',
#   'Орехово-Зуево',
#   'Электросталь',
#   'Москва',
#   'Джубга',
#   'Анапа'],
#  ['Геленджик',
#   'Ижевск',
#   'Казань',
#   'Набережные Челны',
#   'Чебоксары',
#   'Нижний Новгород',
#   'Воткинск',
#   'Пермь',
#   'Дзержинск',
#   'Ковров',
#   'Орехово-Зуево',
#   'Электросталь',
#   'Москва',
#   'Ульяновск',
#   'Джубга',
#   'Анапа',
#   'Балашиха',
#   'Волгоград',
#   'Элиста',
#   'Каспийск',
#   'Дербент',
#   'Избербаш',
#   'Махачкала',
#   'Кизляр',
#   'Тамбов'],
#  ['Геленджик',
#   'Пермь',
#   'Воткинск',
#   'Ижевск',
#   'Набережные Челны',
#   'Казань',
#   'Чебоксары',
#   'Нижний Новгород',
#   'Дзержинск',
#   'Ковров',
#   'Владимир',
#   'Электросталь',
#   'Москва',
#   'Джубга',
#   'Анапа'],
#  ['Краснодар',
#   'Кропоткин',
#   'Славянск-на-Кубани',
#   'Темрюк',
#   'Усть-Лабинск',
#   'Астрахань',
#   'Геленджик',
#   'Назрань',
#   'Владикавказ',
#   'Волгоград',
#   'Саратов',
#   'Балаково',
#   'Сызрань',
#   'Тольятти',
#   'Самара',
#   'Уфа',
#   'Джубга',
#   'Новомихайловский',
#   'Туапсе',
#   'Сочи',
#   'Анапа',
#   'Москва',
#   'Дербент',
#   'Избербаш',
#   'Махачкала',
#   'Ульяновск',
#   'Казань',
#   'Минеральные Воды',
#   'Пенза',
#   'Саранск',
#   'Нижний Новгород',
#   'Кизляр',
#   'Каспийск',
#   'Тамбов',
#   'Владимир',
#   'Иваново',
#   'Кисловодск',
#   'Санкт-Петербург',
#   'Великий Новгород',
#   'Тверь'],
#  ['Москва'],
#  ['Москва',
#   'Воронеж',
#   'Краснодар',
#   'Обнинск',
#   'Курск',
#   'Ростов-на-Дону',
#   'Геленджик',
#   'Новороссийск',
#   'Анапа',
#   'Каменск-Шахтинский',
#   'Шахты',
#   'Кропоткин',
#   'Армавир',
#   'Невинномысск',
#   'Минеральные Воды',
#   'Пятигорск',
#   'Нальчик',
#   'Владикавказ',
#   'Назрань',
#   'Грозный',
#   'Темрюк',
#   'Смоленск',
#   'Санкт-Петербург',
#   'Псков',
#   'Славянск-на-Кубани'],
#  ['Уфа',
#   'Ковров',
#   'Орехово-Зуево',
#   'Электросталь',
#   'Набережные Челны',
#   'Ижевск',
#   'Чебоксары',
#   'Дзержинск',
#   'Балашиха',
#   'Старая Купавна',
#   'Монино',
#   'Ногинск',
#   'Воткинск',
#   'Казань',
#   'Владимир',
#   'Нижний Новгород',
#   'Москва'],
#  ['Воронеж',
#   'Москва',
#   'Пятигорск',
#   'Ставрополь',
#   'Владикавказ',
#   'Нальчик',
#   'Прохладный',
#   'Минеральные Воды',
#   'Элиста',
#   'Волгоград',
#   'Саратов',
#   'Балаково',
#   'Сызрань',
#   'Тольятти',
#   'Самара',
#   'Уфа',
#   'Шахты',
#   'Каменск-Шахтинский',
#   'Белгород',
#   'Курск',
#   'Брянск',
#   'Новочеркасск'],
#  ['Воронеж',
#   'Ессентуки',
#   'Москва',
#   'Пятигорск',
#   'Михайловск',
#   'Ставрополь',
#   'Прохладный',
#   'Минеральные Воды',
#   'Владикавказ',
#   'Назрань',
#   'Грозный',
#   'Сызрань',
#   'Тольятти',
#   'Самара',
#   'Волгоград',
#   'Саратов',
#   'Балаково',
#   'Уфа',
#   'Санкт-Петербург',
#   'Тверь',
#   'Шахты',
#   'Каменск-Шахтинский',
#   'Курск',
#   'Белгород',
#   'Брянск',
#   'Тула',
#   'Новочеркасск'],
#  ['Абакан', 'Красноярск'],
#  ['Кызыл', 'Красноярск'],
#  ['Кызыл', 'Томск', 'Абакан'],
#  ['Кизляр',
#   'Невинномысск',
#   'Армавир',
#   'Кропоткин',
#   'Краснодар',
#   'Новороссийск',
#   'Пятигорск',
#   'Астрахань',
#   'Элиста',
#   'Волгоград',
#   'Саратов',
#   'Сызрань',
#   'Ульяновск',
#   'Казань',
#   'Пенза',
#   'Саранск',
#   'Нижний Новгород',
#   'Тамбов',
#   'Владимир',
#   'Иваново',
#   'Москва',
#   'Тверь',
#   'Великий Новгород',
#   'Санкт-Петербург'],
#  ['Невинномысск',
#   'Армавир',
#   'Кропоткин',
#   'Краснодар',
#   'Новороссийск',
#   'Астрахань',
#   'Элиста',
#   'Волгоград',
#   'Саратов',
#   'Сызрань',
#   'Ульяновск',
#   'Казань',
#   'Пенза',
#   'Саранск',
#   'Нижний Новгород',
#   'Тамбов',
#   'Владимир',
#   'Иваново',
#   'Москва',
#   'Тверь',
#   'Великий Новгород',
#   'Санкт-Петербург'],
#  ['Невинномысск',
#   'Армавир',
#   'Кропоткин',
#   'Краснодар',
#   'Новороссийск',
#   'Элиста',
#   'Волгоград',
#   'Саратов',
#   'Пенза',
#   'Саранск',
#   'Нижний Новгород',
#   'Тамбов',
#   'Владимир',
#   'Иваново',
#   'Москва',
#   'Тверь',
#   'Великий Новгород',
#   'Санкт-Петербург'],
#  ['Невинномысск',
#   'Армавир',
#   'Кропоткин',
#   'Краснодар',
#   'Новороссийск',
#   'Москва',
#   'Астрахань',
#   'Волгоград',
#   'Саратов',
#   'Сызрань',
#   'Ульяновск',
#   'Казань',
#   'Элиста',
#   'Пенза',
#   'Саранск',
#   'Нижний Новгород',
#   'Тамбов',
#   'Владимир',
#   'Иваново',
#   'Санкт-Петербург',
#   'Великий Новгород',
#   'Тверь'],
#  ['Воронеж',
#   'Москва',
#   'Анапа',
#   'Пятигорск',
#   'Сергиев Посад',
#   'Серпухов',
#   'Краснодар',
#   'Ростов-на-Дону',
#   'Элиста',
#   'Волгоград',
#   'Михайловск',
#   'Ставрополь',
#   'Нальчик',
#   'Прохладный',
#   'Минеральные Воды',
#   'Назрань',
#   'Грозный',
#   'Ярославль',
#   'Иваново',
#   'Саратов',
#   'Балаково',
#   'Сызрань',
#   'Тольятти',
#   'Самара',
#   'Уфа',
#   'Тихорецк',
#   'Армавир',
#   'Кропоткин',
#   'Шахты',
#   'Каменск-Шахтинский',
#   'Курск',
#   'Белгород',
#   'Брянск',
#   'Новочеркасск'],
#  ['Вельск', 'Котлас', 'Вологда'],
#  ['Томск', 'Новосибирск'],
#  ['Прокопьевск',
#   'Барнаул',
#   'Бийск',
#   'Красноярск',
#   'Юрга',
#   'Кемерово',
#   'Новосибирск'],
#  ['Астрахань',
#   'Краснодар',
#   'Кропоткин',
#   'Ростов-на-Дону',
#   'Славянск-на-Кубани',
#   'Элиста',
#   'Туапсе',
#   'Джубга',
#   'Геленджик',
#   'Новороссийск',
#   'Сочи',
#   'Лиски',
#   'Каменск-Шахтинский',
#   'Шахты',
#   'Тула',
#   'Москва',
#   'Воронеж',
#   'Усть-Лабинск',
#   'Армавир',
#   'Невинномысск',
#   'Минеральные Воды',
#   'Анапа',
#   'Курск',
#   'Брянск',
#   'Волгоград',
#   'Белая Калитва'],
#  ['Бийск', 'Томск'],
#  ['Томск', 'Барнаул'],
#  ['Сочи', 'Туапсе', 'Джубга', 'Горячий Ключ', 'Геленджик'],
#  ['Сочи',
#   'Туапсе',
#   'Краснодар',
#   'Кореновск',
#   'Батайск',
#   'Ростов-на-Дону',
#   'Таганрог',
#   'Москва',
#   'Воронеж',
#   'Тула',
#   'Астрахань',
#   'Джубга',
#   'Геленджик',
#   'Армавир',
#   'Кропоткин',
#   'Ставрополь',
#   'Новомихайловский',
#   'Невинномысск',
#   'Минеральные Воды',
#   'Пятигорск',
#   'Георгиевск'],
#  ['Ярославль',
#   'Нижний Новгород',
#   'Вологда',
#   'Владикавказ',
#   'Волгоград',
#   'Элиста',
#   'Каспийск',
#   'Дербент',
#   'Избербаш',
#   'Махачкала',
#   'Кизляр',
#   'Тамбов'],
#  ['Новомихайловский',
#   'Туапсе',
#   'Сочи',
#   'Джубга',
#   'Горячий Ключ',
#   'Геленджик',
#   'Ростов-на-Дону',
#   'Краснодар',
#   'Аксай',
#   'Новочеркасск',
#   'Шахты',
#   'Каменск-Шахтинский',
#   'Белгород'],
#  ['Санкт-Петербург'],
#  ['Санкт-Петербург'],
#  ['Архангельск', 'Ярославль', 'Вологда'],
#  ['Уфа', 'Нефтекамск', 'Ижевск'],
#  ['Ростов-на-Дону',
#   'Аксай',
#   'Новочеркасск',
#   'Шахты',
#   'Каменск-Шахтинский',
#   'Воронеж',
#   'Москва'],
#  ['Казань',
#   'Пермь',
#   'Воткинск',
#   'Набережные Челны',
#   'Дзержинск',
#   'Ковров',
#   'Орехово-Зуево',
#   'Электросталь',
#   'Сосновый Бор',
#   'Краснокамск',
#   'Ногинск',
#   'Монино',
#   'Старая Купавна',
#   'Балашиха',
#   'Москва',
#   'Киров',
#   'Нефтекамск',
#   'Уфа',
#   'Белорецк',
#   'Сыктывкар',
#   'Чебоксары',
#   'Нижний Новгород',
#   'Владимир',
#   'Сарапул'],
#  ['Ижевск', 'Киров', 'Уфа', 'Белорецк', 'Сыктывкар', 'Сарапул'],
#  ['Кемерово', 'Томск', 'Новосибирск'],
#  [],
#  ['Каменск-Шахтинский',
#   'Шахты',
#   'Новочеркасск',
#   'Лиски',
#   'Светлоград',
#   'Майкоп'],
#  ['Набережные Челны', 'Казань', 'Киров', 'Сыктывкар', 'Ухта', 'Альметьевск'],
#  ['Москва',
#   'Саратов',
#   'Геленджик',
#   'Новороссийск',
#   'Саранск',
#   'Пенза',
#   'Волгоград',
#   'Джубга',
#   'Туапсе',
#   'Новомихайловский',
#   'Анапа'],
#  ['Новомихайловский',
#   'Туапсе',
#   'Геленджик',
#   'Элиста',
#   'Джубга',
#   'Армавир',
#   'Майкоп',
#   'Апшеронск',
#   'Горячий Ключ',
#   'Сочи',
#   'Кропоткин',
#   'Усть-Лабинск',
#   'Краснодар',
#   'Темрюк',
#   'Славянск-на-Кубани',
#   'Анапа',
#   'Кизляр',
#   'Махачкала',
#   'Избербаш',
#   'Дербент',
#   'Минеральные Воды',
#   'Кисловодск'],
#  ['Чебоксары',
#   'Казань',
#   'Ульяновск',
#   'Набережные Челны',
#   'Воткинск',
#   'Пермь',
#   'Ижевск',
#   'Нижний Новгород',
#   'Ковров',
#   'Владимир',
#   'Орехово-Зуево',
#   'Электросталь',
#   'Москва',
#   'Новороссийск',
#   'Геленджик',
#   'Джубга',
#   'Туапсе',
#   'Новомихайловский',
#   'Анапа'],
#  ['Москва',
#   'Новороссийск',
#   'Геленджик',
#   'Джубга',
#   'Туапсе',
#   'Новомихайловский',
#   'Анапа'],
#  ['Астрахань'],
#  ['Астрахань',
#   'Минеральные Воды',
#   'Аксай',
#   'Ростов-на-Дону',
#   'Новочеркасск',
#   'Москва',
#   'Каменск-Шахтинский',
#   'Шахты',
#   'Новомосковск',
#   'Воронеж',
#   'Тула'],
#  ['Казань',
#   'Москва',
#   'Владимир',
#   'Нижний Новгород',
#   'Чебоксары',
#   'Оренбург',
#   'Анапа',
#   'Геленджик',
#   'Волгоград',
#   'Ростов-на-Дону',
#   'Краснодар',
#   'Астрахань',
#   'Дербент',
#   'Избербаш',
#   'Махачкала',
#   'Кизляр',
#   'Элиста',
#   'Самара'],
#  ['Ростов-на-Дону', 'Таганрог', 'Невинномысск', 'Ставрополь', 'Черкесск'],
#  ['Невинномысск',
#   'Ставрополь',
#   'Карачаевск',
#   'Теберда',
#   'Москва',
#   'Тула',
#   'Воронеж',
#   'Каменск-Шахтинский',
#   'Шахты',
#   'Новочеркасск',
#   'Усть-Лабинск',
#   'Ростов-на-Дону',
#   'Аксай'],
#  ['Ростов-на-Дону', 'Таганрог', 'Невинномысск', 'Черкесск', 'Ставрополь'],
#  ['Пермь',
#   'Ижевск',
#   'Набережные Челны',
#   'Ковров',
#   'Орехово-Зуево',
#   'Электросталь',
#   'Казань',
#   'Чебоксары',
#   'Балашиха',
#   'Старая Купавна',
#   'Монино',
#   'Ногинск',
#   'Дзержинск',
#   'Владимир',
#   'Нижний Новгород',
#   'Москва'],
#  ['Нижний Новгород',
#   'Саратов',
#   'Геленджик',
#   'Анапа',
#   'Арзамас',
#   'Пенза',
#   'Волгоград',
#   'Дербент',
#   'Избербаш',
#   'Каспийск',
#   'Махачкала',
#   'Кизляр',
#   'Элиста'],
#  ['Уфа'],
#  ['Чебоксары', 'Йошкар-Ола', 'Казань', 'Киров', 'Сыктывкар', 'Васильево'],
#  ['Воткинск',
#   'Ижевск',
#   'Набережные Челны',
#   'Казань',
#   'Чебоксары',
#   'Нижний Новгород',
#   'Дзержинск',
#   'Ковров',
#   'Владимир',
#   'Орехово-Зуево',
#   'Москва',
#   'Пермь'],
#  ['Москва',
#   'Губкин',
#   'Старый Оскол',
#   'Воронеж',
#   'Славянск-на-Кубани',
#   'Каменск-Шахтинский',
#   'Шахты',
#   'Ростов-на-Дону',
#   'Краснодар',
#   'Саратов',
#   'Кропоткин',
#   'Армавир',
#   'Невинномысск',
#   'Минеральные Воды',
#   'Пятигорск',
#   'Нальчик',
#   'Владикавказ',
#   'Назрань',
#   'Грозный',
#   'Кореновск',
#   'Аксай',
#   'Новочеркасск',
#   'Волгоград'],
#  ['Москва',
#   'Воронеж',
#   'Брянск',
#   'Ростов-на-Дону',
#   'Краснодар',
#   'Геленджик',
#   'Новороссийск',
#   'Анапа',
#   'Нальчик',
#   'Владикавказ',
#   'Назрань',
#   'Грозный',
#   'Каменск-Шахтинский',
#   'Шахты',
#   'Кропоткин',
#   'Армавир',
#   'Невинномысск',
#   'Минеральные Воды',
#   'Пятигорск',
#   'Темрюк',
#   'Славянск-на-Кубани'],
#  ['Ставрополь'],
#  ['Ставрополь', 'Элиста', 'Астрахань'],
#  ['Астрахань',
#   'Ставрополь',
#   'Михайловск',
#   'Аксай',
#   'Ростов-на-Дону',
#   'Элиста',
#   'Славянск-на-Кубани',
#   'Темрюк',
#   'Новочеркасск',
#   'Энем',
#   'Ильский',
#   'Сочи',
#   'Туапсе',
#   'Новомихайловский',
#   'Джубга',
#   'Геленджик',
#   'Анапа',
#   'Москва',
#   'Каменск-Шахтинский',
#   'Шахты',
#   'Черкесск',
#   'Псебай',
#   'Воронеж',
#   'Абинск',
#   'Крымск'],
#  [],
#  ['Белгород', 'Воронеж', 'Москва', 'Саратов', 'Волгоград'],
#  ['Лиски',
#   'Новочеркасск',
#   'Аксай',
#   'Ростов-на-Дону',
#   'Шахты',
#   'Каменск-Шахтинский',
#   'Светлоград'],
#  ['Ижевск', 'Набережные Челны'],
#  ['Ижевск',
#   'Набережные Челны',
#   'Чебоксары',
#   'Балашиха',
#   'Старая Купавна',
#   'Монино',
#   'Ногинск',
#   'Дзержинск',
#   'Воткинск',
#   'Владимир',
#   'Казань',
#   'Москва'],
#  ['Воронеж',
#   'Минеральные Воды',
#   'Ростов-на-Дону',
#   'Тула',
#   'Владикавказ',
#   'Мытищи',
#   'Домодедово',
#   'Москва',
#   'Жуковский'],
#  ['Владикавказ', 'Минеральные Воды', 'Ростов-на-Дону'],
#  ['Аксай',
#   'Ростов-на-Дону',
#   'Новочеркасск',
#   'Каменск-Шахтинский',
#   'Москва',
#   'Шахты',
#   'Воронеж',
#   'Новомосковск',
#   'Тула'],
#  ['Нижний Тагил', 'Аша', 'Сим', 'Уфа'],
#  [],
#  ['Ставрополь', 'Усть-Лабинск', 'Кропоткин'],
#  [],
#  ['Киров',
#   'Сыктывкар',
#   'Йошкар-Ола',
#   'Казань',
#   'Стерлитамак',
#   'Уфа',
#   'Набережные Челны'],
#  ['Казань',
#   'Нижнекамск',
#   'Набережные Челны',
#   'Бугульма',
#   'Уфа',
#   'Оренбург',
#   'Салават',
#   'Стерлитамак'],
#  ['Кировск'],
#  ['Кировск', 'Псков'],
#  ['Шахты',
#   'Каменск-Шахтинский',
#   'Лиски',
#   'Новочеркасск',
#   'Аксай',
#   'Ростов-на-Дону',
#   'Светлоград'],
#  ['Екатеринбург'],
#  ['Ревда', 'Первоуральск', 'Екатеринбург'],
#  ['Ревда', 'Первоуральск', 'Екатеринбург'],
#  ['Тюмень', 'Ханты-Мансийск'],
#  ['Тобольск', 'Ханты-Мансийск'],
#  ['Джубга', 'Геленджик', 'Новомихайловский'],
#  ['Воронеж',
#   'Владикавказ',
#   'Каменск-Шахтинский',
#   'Шахты',
#   'Новочеркасск',
#   'Тихорецк',
#   'Кропоткин',
#   'Армавир',
#   'Невинномысск',
#   'Минеральные Воды',
#   'Пятигорск',
#   'Нальчик',
#   'Кочубеевское',
#   'Волгоград',
#   'Элиста',
#   'Махачкала',
#   'Кизляр',
#   'Тамбов',
#   'Санкт-Петербург',
#   'Каспийск',
#   'Дербент',
#   'Избербаш'],
#  ['Москва'],
#  ['Новомихайловский', 'Джубга', 'Геленджик'],
#  ['Киров', 'Нефтекамск', 'Уфа', 'Ижевск'],
#  ['Сергиев Посад',
#   'Пушкино',
#   'Мытищи',
#   'Вологда',
#   'Ярославль',
#   'Переславль-Залесский'],
#  ['Сергиев Посад',
#   'Пушкино',
#   'Мытищи',
#   'Ярославль',
#   'Череповец',
#   'Вологда',
#   'Переславль-Залесский'],
#  ['Уфа',
#   'Казань',
#   'Киров',
#   'Москва',
#   'Балашиха',
#   'Владимир',
#   'Дзержинск',
#   'Нижний Новгород'],
#  ['Джубга', 'Геленджик', 'Анапа'],
#  ['Пенза',
#   'Гай',
#   'Альметьевск',
#   'Сызрань',
#   'Тольятти',
#   'Самара',
#   'Москва',
#   'Нижний Новгород',
#   'Чебоксары',
#   'Ульяновск',
#   'Городище',
#   'Бугульма',
#   'Казань'],
#  ['Вологда', 'Ярославль'],
#  ['Москва', 'Псков', 'Гатчина', 'Санкт-Петербург', 'Пушкин'],
#  [],
#  ['Ставрополь', 'Усть-Лабинск', 'Кропоткин'],
#  ['Ставрополь', 'Усть-Лабинск', 'Кропоткин'],
#  ['Альметьевск', 'Нижнекамск', 'Набережные Челны', 'Казань', 'Оренбург'],
#  ['Бугульма', 'Альметьевск'],
#  ['Набережные Челны', 'Киров', 'Альметьевск', 'Казань'],
#  ['Ярославль', 'Котлас', 'Сыктывкар', 'Вологда', 'Череповец'],
#  ['Белгород', 'Каменск-Шахтинский', 'Шахты', 'Курск', 'Брянск'],
#  ['Киров', 'Йошкар-Ола', 'Сыктывкар'],
#  ['Ярославль', 'Сыктывкар', 'Великий Устюг', 'Вологда', 'Архангельск'],
#  ['Оренбург'],
#  ['Ставрополь', 'Усть-Лабинск', 'Кропоткин'],
#  ['Каменск-Шахтинский',
#   'Шахты',
#   'Новочеркасск',
#   'Тихорецк',
#   'Кропоткин',
#   'Армавир',
#   'Невинномысск',
#   'Минеральные Воды',
#   'Пятигорск',
#   'Нальчик'],
#  ['Москва', 'Санкт-Петербург'],
#  ['Новосибирск'],
#  ['Советск', 'Киров'],
#  ['Оренбург'],
#  ['Тула', 'Воронеж', 'Смоленск'],
#  ['Усть-Илимск'],
#  ['Братск'],
#  ['Уфа', 'Аша', 'Сим'],
#  ['Аша', 'Сим'],
#  ['Череповец', 'Домодедово', 'Москва', 'Жуковский'],
#  ['Усть-Лабинск',
#   'Ростов-на-Дону',
#   'Аксай',
#   'Новочеркасск',
#   'Шахты',
#   'Каменск-Шахтинский',
#   'Воронеж',
#   'Москва']]

# %%
# Calculate for each departure city the number of cities it is possible to travel to
city_counts = []
for k in list(data.keys()):
    city_counts.append(len(data[k]))
city_counts
# Out:
# [82,
#  56,
#  62,
#  46,
#  123,
#  51,
#  53,
#  30,
#  26,
#  17,
#  48,
#  40,
#  28,
#  18,
#  49,
#  45,
#  43,
#  53,
#  10,
#  33,
#  28,
#  50,
#  39,
#  47,
#  9,
#  3,
#  15,
#  35,
#  19,
#  6,
#  1,
#  13,
#  20,
#  55,
#  21,
#  47,
#  14,
#  15,
#  7,
#  4,
#  2,
#  7,
#  1,
#  36,
#  43,
#  0,
#  30,
#  11,
#  2,
#  2,
#  16,
#  38,
#  19,
#  13,
#  18,
#  8,
#  13,
#  38,
#  1,
#  6,
#  7,
#  26,
#  17,
#  1,
#  27,
#  20,
#  30,
#  19,
#  20,
#  15,
#  3,
#  5,
#  8,
#  10,
#  26,
#  21,
#  15,
#  25,
#  15,
#  40,
#  1,
#  25,
#  17,
#  22,
#  27,
#  2,
#  2,
#  3,
#  24,
#  22,
#  18,
#  22,
#  34,
#  3,
#  2,
#  7,
#  26,
#  2,
#  2,
#  5,
#  21,
#  12,
#  13,
#  1,
#  1,
#  3,
#  3,
#  7,
#  24,
#  6,
#  3,
#  0,
#  6,
#  6,
#  11,
#  22,
#  19,
#  7,
#  1,
#  11,
#  18,
#  5,
#  13,
#  5,
#  16,
#  13,
#  1,
#  6,
#  12,
#  23,
#  21,
#  1,
#  3,
#  25,
#  0,
#  5,
#  7,
#  2,
#  12,
#  9,
#  3,
#  9,
#  4,
#  0,
#  3,
#  0,
#  7,
#  8,
#  1,
#  2,
#  7,
#  1,
#  3,
#  3,
#  2,
#  2,
#  3,
#  22,
#  1,
#  3,
#  4,
#  6,
#  7,
#  8,
#  3,
#  13,
#  2,
#  5,
#  0,
#  3,
#  3,
#  5,
#  2,
#  4,
#  5,
#  5,
#  3,
#  5,
#  1,
#  3,
#  10,
#  2,
#  1,
#  2,
#  1,
#  3,
#  1,
#  1,
#  3,
#  2,
#  4,
#  8]

# %%
# Create a dataframe with the city name and the number of routes for each city
df_1 = pd.DataFrame([city_counts], columns=list(data.keys()))
df_1
# Out:
#    Ростов-на-Дону  Каменск-Шахтинский  Воронеж  Джубга  Москва  Шахты  \
# 0              82                  56       62      46     123     51
#
#    Новочеркасск  Аксай  Лиски  Батайск  ...  Новокузнецк  Васильево  Городище  \
# 0            53     30     26       17  ...            1          2         1
#
#    Калуга  Братск  Усть-Илимск  Первоуральск  Ревда  Переславль-Залесский  \
# 0       3       1            1             3      2                     4
#
#    Псебай
# 0       8
#
# [1 rows x 192 columns]

# %%
# Create a dataframe with all the routes from this city
df_2 = pd.DataFrame(dict([(k, pd.Series(v)) for k, v in data.items()]))
df_2.tail(5)
# Out:
#     Ростов-на-Дону Каменск-Шахтинский Воронеж Джубга       Москва Шахты  \
# 118            NaN                NaN     NaN    NaN     Тольятти   NaN
# 119            NaN                NaN     NaN    NaN  Светлогорск   NaN
# 120            NaN                NaN     NaN    NaN  Краснокамск   NaN
# 121            NaN                NaN     NaN    NaN     Каспийск   NaN
# 122            NaN                NaN     NaN    NaN     Избербаш   NaN
#
#     Новочеркасск Аксай Лиски Батайск  ... Новокузнецк Васильево Городище  \
# 118          NaN   NaN   NaN     NaN  ...         NaN       NaN      NaN
# 119          NaN   NaN   NaN     NaN  ...         NaN       NaN      NaN
# 120          NaN   NaN   NaN     NaN  ...         NaN       NaN      NaN
# 121          NaN   NaN   NaN     NaN  ...         NaN       NaN      NaN
# 122          NaN   NaN   NaN     NaN  ...         NaN       NaN      NaN
#
#     Калуга Братск Усть-Илимск Первоуральск Ревда Переславль-Залесский Псебай
# 118    NaN    NaN         NaN          NaN   NaN                  NaN    NaN
# 119    NaN    NaN         NaN          NaN   NaN                  NaN    NaN
# 120    NaN    NaN         NaN          NaN   NaN                  NaN    NaN
# 121    NaN    NaN         NaN          NaN   NaN                  NaN    NaN
# 122    NaN    NaN         NaN          NaN   NaN                  NaN    NaN
#
# [5 rows x 192 columns]

# %%
# Concatenate dataframes where the first row is a number of routes and then
# go all the routes for each city 
df = pd.concat([df_1, df_2], ignore_index=True, axis=0)
df = df.fillna('-')
df.head(10)
# Out:
#      Ростов-на-Дону Каменск-Шахтинский             Воронеж        Джубга  \
# 0                82                 56                  62            46
# 1        Ставрополь             Москва               Аксай     Краснодар
# 2  Минеральные Воды         Ставрополь  Каменск-Шахтинский     Кропоткин
# 3      Невинномысск         Михайловск              Москва    Ставрополь
# 4          Приморск              Аксай        Новочеркасск         Анапа
# 5         Пятигорск            Воронеж      Ростов-на-Дону     Геленджик
# 6          Тихорецк              Лиски          Ставрополь  Новороссийск
# 7            Москва       Новочеркасск                Тула          Сочи
# 8        Михайловск     Ростов-на-Дону          Михайловск        Туапсе
# 9             Аксай               Тула          Светлоград        Самара
#
#                Москва           Шахты        Новочеркасск               Аксай  \
# 0                 123              51                  53                  30
# 1          Волгодонск      Ставрополь          Ставрополь          Ставрополь
# 2             Воронеж      Михайловск          Михайловск          Светлоград
# 3                Тула      Светлоград               Аксай             Воронеж
# 4               Шахты            Тула             Воронеж  Каменск-Шахтинский
# 5        Новочеркасск          Москва  Каменск-Шахтинский               Лиски
# 6               Лиски         Воронеж               Лиски              Москва
# 7               Аксай  Ростов-на-Дону              Москва        Новочеркасск
# 8  Каменск-Шахтинский   Белая Калитва      Ростов-на-Дону      Ростов-на-Дону
# 9      Ростов-на-Дону       Волгоград                Тула                Тула
#
#                 Лиски           Батайск  ...  Новокузнецк Васильево  Городище  \
# 0                  26                17  ...            1         2         1
# 1          Ставрополь        Ставрополь  ...  Новосибирск   Советск  Оренбург
# 2      Ростов-на-Дону        Михайловск  ...            -     Киров         -
# 3               Шахты        Светлоград  ...            -         -         -
# 4  Каменск-Шахтинский        Георгиевск  ...            -         -         -
# 5        Новочеркасск         Пятигорск  ...            -         -         -
# 6               Аксай  Минеральные Воды  ...            -         -         -
# 7             Батайск            Джубга  ...            -         -         -
# 8          Михайловск  Новомихайловский  ...            -         -         -
# 9             Воронеж            Туапсе  ...            -         -         -
#
#      Калуга       Братск Усть-Илимск Первоуральск Ревда Переславль-Залесский  \
# 0         3            1           1            3     2                    4
# 1      Тула  Усть-Илимск      Братск          Уфа   Аша            Череповец
# 2   Воронеж            -           -          Аша   Сим           Домодедово
# 3  Смоленск            -           -          Сим     -               Москва
# 4         -            -           -            -     -            Жуковский
# 5         -            -           -            -     -                    -
# 6         -            -           -            -     -                    -
# 7         -            -           -            -     -                    -
# 8         -            -           -            -     -                    -
# 9         -            -           -            -     -                    -
#
#                Псебай
# 0                   8
# 1        Усть-Лабинск
# 2      Ростов-на-Дону
# 3               Аксай
# 4        Новочеркасск
# 5               Шахты
# 6  Каменск-Шахтинский
# 7             Воронеж
# 8              Москва
# 9                   -
#
# [10 rows x 192 columns]
